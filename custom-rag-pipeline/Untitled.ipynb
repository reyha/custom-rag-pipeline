# %%
# !pip install llama-index
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(input_files=["../../Downloads/ConceptsofBiology-WEB.pdf"]).load_data()

# %%
documents
# Out:
# [Document(id_='96527e17-fd75-474c-b277-06c346d8cd0d', embedding=None, metadata={'page_label': '1', 'file_name': 'ConceptsofBiology-WEB.pdf', 'file_path': '../../Downloads/ConceptsofBiology-WEB.pdf', 'file_type': 'application/pdf', 'file_size': 153179709, 'creation_date': '2024-03-13', 'last_modified_date': '2024-03-13'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
